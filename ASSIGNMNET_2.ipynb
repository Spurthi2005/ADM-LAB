# %% [markdown]
# <a href="https://colab.research.google.com/github/Spurthi2005/ADM-LAB/blob/main/ASSIGNMNET_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv("employee_performance.csv")


print(df.info())
print(df.head())

print(df.describe())


df['Department'] = df['Department'].astype('category').cat.codes
df['Salary_per_YearExperience'] = df['Monthly_Salary'] / (df['Years_of_Experience'] + 1)
plt.figure(figsize=(8, 6))
sns.histplot(df['Monthly_Salary'], bins=20, kde=True, color='blue')
plt.title('Histogram of Monthly Salaries')
plt.xlabel('Monthly Salary')
plt.ylabel('Frequency')
plt.show()


plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['Years_of_Experience'], y=df['Performance_Score'], hue=df['Monthly_Salary'], palette='coolwarm', size=df['Monthly_Salary'], sizes=(20, 200))
plt.title('Scatter Plot: Years of Experience vs. Performance Score')
plt.xlabel('Years of Experience')
plt.ylabel('Performance Score')
plt.colorbar(label='Monthly Salary')
plt.show()


plt.figure(figsize=(8, 6))
sns.heatmap(df[['Monthly_Salary', 'Years_of_Experience', 'Performance_Score']].corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Heatmap of Numerical Features')
plt.show()


df.to_csv("transformed_employee_performance.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          100 non-null    int64
#  1   Department           100 non-null    object
#  2   Monthly_Salary       100 non-null    float64
#  3   Years_of_Experience  100 non-null    int64
#  4   Performance_Score    100 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 4.0+ KB
# None
#    Employee_ID  Department  Monthly_Salary  Years_of_Experience  \
# 0            1          HR       115382.10                   17
# 1            2          HR        32428.50                    6
# 2            3  Operations        48202.18                    9
# 3            4          IT        39488.41                    1
# 4            5          HR        64898.09                    6
#
#    Performance_Score
# 0                 10
# ...
